# %%
import pandas as pd 
import pandas as pd

df = pd.read_csv(
    r"C:\Users\acer\Downloads\archive (1)\zomato.csv",
    encoding="latin1"
    
)

df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df["Aggregate rating"].value_counts()
# Out:
# Aggregate rating
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df["Aggregate rating"].describe()
# Out:
# count    9551.000000
# mean        2.666370
# std         1.516378
# min         0.000000
# 25%         2.500000
# 50%         3.200000
# 75%         3.700000
# max         4.900000
# Name: Aggregate rating, dtype: float64

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
sns.histplot(
    df["Aggregate rating"],
    bins=20
)
plt.show()

# %%
df["City"].value_counts()
# Out:
# City
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
#                   ...
# Lakes Entrance       1
# Mohali               1
# Panchkula            1
# Bandung              1
# Randburg             1
# Name: count, Length: 141, dtype: int64

# %%
df.groupby("City")["Aggregate rating"].mean()
# Out:
# City
# Abu Dhabi          4.300000
# Agra               3.965000
# Ahmedabad          4.161905
# Albany             3.555000
# Allahabad          3.395000
#                      ...
# Weirton            3.900000
# Wellington City    4.250000
# Winchester Bay     3.200000
# Yorkton            3.300000
# ÛÁstanbul          4.292857
# Name: Aggregate rating, Length: 141, dtype: float64

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.groupby("Has Online delivery")["Aggregate rating"].mean()
# Out:
# Has Online delivery
# No     2.465296
# Yes    3.248837
# Name: Aggregate rating, dtype: float64

# %%
df.groupby("Has Table booking")["Aggregate rating"].agg(["mean","count"])
# Out:
#                        mean  count
# Has Table booking
# No                 2.559359   8393
# Yes                3.441969   1158

# %%
df.groupby(
    "Has Table booking"
)["Aggregate rating"].mean().plot(
    kind="bar"
)
# Out:
# <Axes: xlabel='Has Table booking'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(
    x="Has Table booking",
    y="Aggregate rating",
    data=df
)

plt.show()

# %%
df.groupby("Has Table booking")["Aggregate rating"].describe()
# Out:
#                     count      mean       std  min  25%  50%  75%  max
# Has Table booking
# No                 8393.0  2.559359  1.554075  0.0  0.0  3.1  3.6  4.9
# Yes                1158.0  3.441969  0.881305  0.0  3.2  3.6  3.9  4.9

# %%
df.groupby("Average Cost for two")["Aggregate rating"].mean()
# Out:
# Average Cost for two
# 0         3.761111
# 7         3.725000
# 10        4.011719
# 15        3.575000
# 20        3.696000
#             ...
# 300000    4.000000
# 350000    4.300000
# 450000    4.200000
# 500000    4.900000
# 800000    4.350000
# Name: Aggregate rating, Length: 140, dtype: float64

# %%
df["Average Cost for two"]
# Out:
# 0       1100
# 1       1200
# 2       4000
# 3       1500
# 4       1500
#         ...
# 9546      80
# 9547     105
# 9548     170
# 9549     120
# 9550      55
# Name: Average Cost for two, Length: 9551, dtype: int64

# %%
df.groupby("Price range")["Aggregate rating"].mean()
# Out:
# Price range
# 1    1.999887
# 2    2.941054
# 3    3.683381
# 4    3.817918
# Name: Aggregate rating, dtype: float64

# %%
df.groupby("Cuisines")["Aggregate rating"].mean()
# Out:
# Cuisines
# Afghani                                      0.725
# Afghani, Mughlai, Chinese                    0.000
# Afghani, North Indian                        0.000
# Afghani, North Indian, Pakistani, Arabian    0.000
# African                                      4.700
#                                              ...
# Western, Asian, Cafe                         4.200
# Western, Fusion, Fast Food                   3.200
# World Cuisine                                4.900
# World Cuisine, Mexican, Italian              4.400
# World Cuisine, Patisserie, Cafe              4.200
# Name: Aggregate rating, Length: 1825, dtype: float64

# %%
df.groupby("Country Code")["Aggregate rating"].mean()
# Out:
# Country Code
# 1      2.523324
# 14     3.658333
# 30     3.763333
# 37     3.575000
# 94     4.295238
# 148    4.262500
# 162    4.468182
# 166    4.060000
# 184    3.575000
# 189    4.210000
# 191    3.870000
# 208    4.300000
# 214    4.233333
# 215    4.087500
# 216    4.004378
# Name: Aggregate rating, dtype: float64

# %%
country_df=pd.read_excel(r"C:\Users\acer\Downloads\archive (1)\Country-Code.xlsx")
country_df.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df=df.merge(country_df,
            on= "Country Code",
            how="left"
           )

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.groupby("City")["Aggregate rating"].mean().sort_values(ascending=False)
# Out:
# City
# Inner City          4.900000
# Quezon City         4.800000
# Makati City         4.650000
# Pasig City          4.633333
# Mandaluyong City    4.625000
#                       ...
# New Delhi           2.438845
# Montville           2.400000
# Mc Millan           2.400000
# Noida               2.036204
# Faridabad           1.866932
# Name: Aggregate rating, Length: 141, dtype: float64

# %%
df["City"].value_counts()
# Out:
# City
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
#                   ...
# Lakes Entrance       1
# Mohali               1
# Panchkula            1
# Bandung              1
# Randburg             1
# Name: count, Length: 141, dtype: int64

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
city_stats=df.groupby("City").agg({
    'Aggregate rating':'mean',
    'Restaurant ID':'count'
})

city_stats.rename(
    columns={'Restaurant ID':'Restorant Count'},
             inplace=True
)
print(city_stats.sort_values(
by='Aggregate rating',
ascending=False
).head(20))
# Out:
#                   Aggregate rating  Restorant Count
# City
# Inner City                4.900000                2
# Quezon City               4.800000                1
# Makati City               4.650000                2
# Pasig City                4.633333                3
# Mandaluyong City          4.625000                4
# Beechworth                4.600000                1
# London                    4.535000               20
# Taguig City               4.525000                4
# Secunderabad              4.500000                2
# Lincoln                   4.500000                1
# Tagaytay City             4.500000                1
# Orlando                   4.475000               20
# Tampa Bay                 4.410000               20
# Rest of Hawaii            4.410000               20
# Palm Cove                 4.400000                1
# Tanunda                   4.400000                1
# Bangalore                 4.375000               20
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df["Average Cost for two"].head()
# Out:
# 0    1100
# 1    1200
# 2    4000
# 3    1500
# 4    1500
# Name: Average Cost for two, dtype: int64

# %%
df[["Average Cost for two","Aggregate rating"]].corr()
# Out:
#                       Average Cost for two  Aggregate rating
# Average Cost for two              1.000000          0.051792
# Aggregate rating                  0.051792          1.000000

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
sns.scatterplot(
    x="Average Cost for two",
    y="Aggregate rating",
    data=df
)
plt.show()

# %%
df["Cuisines"]
# Out:
# 0             French, Japanese, Desserts
# 1                               Japanese
# 2       Seafood, Asian, Filipino, Indian
# 3                        Japanese, Sushi
# 4                       Japanese, Korean
#                       ...
# 9546                             Turkish
# 9547     World Cuisine, Patisserie, Cafe
# 9548              Italian, World Cuisine
# 9549                     Restaurant Cafe
# 9550                                Cafe
# Name: Cuisines, Length: 9551, dtype: object

# %%
df["Cuisines"].value_counts().head()
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Fast Food                354
# North Indian, Mughlai    334
# Name: count, dtype: int64

# %%
df.groupby("Cuisines")["Aggregate rating"].mean().sort_values(ascending=False).head(40)
# Out:
# Cuisines
# Burger, Bar Food, Steak                                        4.900000
# American, Burger, Grill                                        4.900000
# American, Caribbean, Seafood                                   4.900000
# American, Coffee and Tea                                       4.900000
# Mexican, American, Healthy Food                                4.900000
# Italian, Bakery, Continental                                   4.900000
# BBQ, Breakfast, Southern                                       4.900000
# European, German                                               4.900000
# Hawaiian, Seafood                                              4.900000
# Sunda, Indonesian                                              4.900000
# American, BBQ, Sandwich                                        4.900000
# World Cuisine                                                  4.900000
# Continental, Indian                                            4.900000
# ...

# %%
cuisine_stats = df.groupby("Cuisines").agg({
    "Aggregate rating":"mean",
    "Restaurant ID":"count"
})

cuisine_stats.rename(
    columns={"Restaurant ID":"RestaurantCount"},
    inplace=True
)

cuisine_stats.sort_values(
    by="RestaurantCount",
    ascending=False
).head(20)
# Out:
#                                 Aggregate rating  RestaurantCount
# Cuisines
# North Indian                            1.672329              936
# North Indian, Chinese                   2.421722              511
# Chinese                                 2.042090              354
# Fast Food                               2.118362              354
# North Indian, Mughlai                   2.888623              334
# Cafe                                    2.890970              299
# Bakery                                  1.924312              218
# North Indian, Mughlai, Chinese          2.568528              197
# Bakery, Desserts                        2.317647              170
# Street Food                             2.161745              149
# Pizza, Fast Food                        2.629008              131
# Chinese, Fast Food                      2.055085              118
# Mithai, Street Food                     1.893103              116
# ...

# %%
cuisine_stats.head()
# Out:
#                                            Aggregate rating  RestaurantCount
# Cuisines
# Afghani                                               0.725                4
# Afghani, Mughlai, Chinese                             0.000                1
# Afghani, North Indian                                 0.000                1
# Afghani, North Indian, Pakistani, Arabian             0.000                1
# African                                               4.700                1

# %%
df.groupby("Has Online delivery")["Aggregate rating"].agg(["mean","count"])
# Out:
#                          mean  count
# Has Online delivery
# No                   2.465296   7100
# Yes                  3.248837   2451

# %%
df["Votes"]
# Out:
# 0        314
# 1        591
# 2        270
# 3        365
# 4        229
#         ...
# 9546     788
# 9547    1034
# 9548     661
# 9549     901
# 9550     591
# Name: Votes, Length: 9551, dtype: int64

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
sns.scatterplot(x="Aggregate rating", y="Votes",data = df)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Votes'>

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df.groupby("Price range")["Aggregate rating"].mean()
# Out:
# Price range
# 1    1.999887
# 2    2.941054
# 3    3.683381
# 4    3.817918
# Name: Aggregate rating, dtype: float64

# %%
df["City"].value_counts().sort_values(ascending=False)
# Out:
# City
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
#                   ...
# Lakes Entrance       1
# Mohali               1
# Panchkula            1
# Bandung              1
# Randburg             1
# Name: count, Length: 141, dtype: int64

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df["Country"].value_counts().sort_values(ascending=False)
# Out:
# Country
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df["Rating text"].(value_counts()*100)/df.count
# Out:
# Rating text
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: count, dtype: int64

# %%
df.groupby("Rating text")["Votes"].mean()
# Out:
# Rating text
# Average       48.249130
# Excellent    851.770764
# Good         229.351429
# Not rated      0.870112
# Poor          90.715054
# Very Good    520.458758
# Name: Votes, dtype: float64

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df["Switch to order menu"]
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#         ..
# 9546    No
# 9547    No
# 9548    No
# 9549    No
# 9550    No
# Name: Switch to order menu, Length: 9551, dtype: object

# %%
df.groupby("Switch to order menu")["Aggregate rating"].mean()
# Out:
# Switch to order menu
# No    2.66637
# Name: Aggregate rating, dtype: float64

# %%
df["Switch to order menu"].value_counts()
# Out:
# Switch to order menu
# No    9551
# Name: count, dtype: int64
